# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_bc_data.csv")
df.head()
# Out:
#            City Province   Latitude   Longitude      Price  Bedrooms  \
# 0    Revelstoke       BC  50.976585 -118.173149   839000.0       3.0
# 1       Boswell       BC  49.471870 -116.770195  1150000.0       3.0
# 2  West Kelowna       BC  49.825230 -119.603253   149000.0       2.0
# 3       Kelowna       BC  49.821860 -119.480143  1298000.0       5.0
# 4   Maple Ridge       BC  49.221673 -122.596637   759900.0       3.0
#
#    Bathrooms  Property Type  Square Footage
# 0        2.0          Condo           891.0
# 1        2.0  Single Family          1881.0
# 2        1.0  Single Family           912.0
# 3        4.0  Single Family          4374.0
# 4        2.0          Condo          1254.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23136 entries, 0 to 23135
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   City            23136 non-null  str
#  1   Province        23136 non-null  str
#  2   Latitude        23136 non-null  float64
#  3   Longitude       23136 non-null  float64
#  4   Price           23136 non-null  float64
#  5   Bedrooms        23136 non-null  float64
#  6   Bathrooms       23136 non-null  float64
#  7   Property Type   23136 non-null  str
#  8   Square Footage  23136 non-null  float64
# dtypes: float64(6), str(3)
# memory usage: 1.6 MB

# %%
df.describe()
# Out:
#            Latitude     Longitude         Price      Bedrooms     Bathrooms  \
# count  23136.000000  23136.000000  2.313600e+04  23136.000000  23136.000000
# mean      49.375565   -122.483665  1.552201e+06      3.190309      2.692471
# std        1.005299      1.396557  1.793240e+06      1.817441      1.599802
# min       48.335947   -133.701759  5.000000e+04      0.000000      0.000000
# 25%       49.135251   -123.118610  6.750000e+05      2.000000      2.000000
# 50%       49.214393   -122.872641  1.029900e+06      3.000000      2.000000
# 75%       49.278843   -122.614096  1.798000e+06      4.000000      3.000000
# max       59.575279   -114.871134  5.880000e+07     16.000000     14.000000
#
#        Square Footage
# count    23136.000000
# mean      1931.430973
# std       1460.877648
# min        147.000000
# 25%        922.000000
# 50%       1489.000000
# 75%       2482.000000
# max      22318.000000

# %%
numerical_cols = ["Latitude", "Longitude", "Bedrooms", "Bathrooms", "Square Footage", "Price"]

for col in numerical_cols:
    plt.figure(figsize=(8,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
categorical_cols = ["City", "Property Type"]

for col in categorical_cols:
    plt.figure(figsize=(12,4))
    df[col].value_counts().head(20).plot(kind="bar")
    plt.title(f"Top {col} Categories")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
plt.figure(figsize=(14,5))
df["City"].value_counts().head(20).plot(kind="bar")
plt.title("Top 20 Cities by Listing Count")
plt.xlabel("City")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[["Latitude", "Longitude", "Bedrooms", "Bathrooms", "Square Footage", "Price"]].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
